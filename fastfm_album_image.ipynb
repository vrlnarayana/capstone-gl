# %% [markdown]
# <a href="https://colab.research.google.com/github/vrlnarayana/capstone-gl/blob/main/fastfm_album_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request
import requests

API_KEY = '18c5910bdb220f9a8fbb62f9fe9f8f59'

# %%
def get_album_info(artist_name, album_title):
    url = f'http://ws.audioscrobbler.com/2.0/?method=album.getinfo&api_key={API_KEY}&artist={artist_name}&album={album_title}&format=json'
    album_info = requests.get(url).json()
    
    if album_info is None:
        return None

    try:
        return album_info['album']['image'][2]['#text']
    except KeyError:
        return None

# %%
print(get_album_info('Faster Pussy cat','Monster Ballads X-Mas'))
# Out:
# https://lastfm.freetls.fastly.net/i/u/174s/cd3f00323d2a446cab5d332b66144dc6.png

# %%
from PIL import Image

# %%
file = str(get_album_info('Faster Pussy cat','Monster Ballads X-Mas'))
image = Image.open('senti-collection-happy.png')
image1 = Image.open(urllib.request.urlopen(file))

# %%
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1234x613 at 0x7F4F7EA8EEF0>

# %%
display(image1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=174x174 at 0x7F4F7E96D7B8>
